# %%
# !pip install bettermdptools
# Out:
# Requirement already satisfied: bettermdptools in /home/john/.local/lib/python3.10/site-packages (0.4.0)
# Requirement already satisfied: gym<=0.26.2,>=0.26 in /home/john/.local/lib/python3.10/site-packages (from bettermdptools) (0.26.2)
# Requirement already satisfied: matplotlib in /home/john/anaconda3/envs/bettermdptools/lib/python3.10/site-packages (from bettermdptools) (3.7.1)
# Requirement already satisfied: numpy in /home/john/.local/lib/python3.10/site-packages (from bettermdptools) (1.26.1)
# Requirement already satisfied: pandas in /home/john/.local/lib/python3.10/site-packages (from bettermdptools) (2.1.1)
# Requirement already satisfied: pygame in /home/john/.local/lib/python3.10/site-packages (from bettermdptools) (2.5.2)
# Requirement already satisfied: seaborn in /home/john/.local/lib/python3.10/site-packages (from bettermdptools) (0.13.0)
# Requirement already satisfied: tqdm in /home/john/.local/lib/python3.10/site-packages (from bettermdptools) (4.66.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in /home/john/anaconda3/envs/bettermdptools/lib/python3.10/site-packages (from gym<=0.26.2,>=0.26->bettermdptools) (2.2.1)
# Requirement already satisfied: gym-notices>=0.0.4 in /home/john/.local/lib/python3.10/site-packages (from gym<=0.26.2,>=0.26->bettermdptools) (0.0.8)
# Requirement already satisfied: contourpy>=1.0.1 in /home/john/anaconda3/envs/bettermdptools/lib/python3.10/site-packages (from matplotlib->bettermdptools) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /home/john/anaconda3/envs/bettermdptools/lib/python3.10/site-packages (from matplotlib->bettermdptools) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/john/anaconda3/envs/bettermdptools/lib/python3.10/site-packages (from matplotlib->bettermdptools) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/john/anaconda3/envs/bettermdptools/lib/python3.10/site-packages (from matplotlib->bettermdptools) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /home/john/anaconda3/envs/bettermdptools/lib/python3.10/site-packages (from matplotlib->bettermdptools) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in /home/john/anaconda3/envs/bettermdptools/lib/python3.10/site-packages (from matplotlib->bettermdptools) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/john/anaconda3/envs/bettermdptools/lib/python3.10/site-packages (from matplotlib->bettermdptools) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /home/john/.local/lib/python3.10/site-packages (from matplotlib->bettermdptools) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/john/anaconda3/envs/bettermdptools/lib/python3.10/site-packages (from pandas->bettermdptools) (2022.7)
# Requirement already satisfied: tzdata>=2022.1 in /home/john/.local/lib/python3.10/site-packages (from pandas->bettermdptools) (2023.3)
# Requirement already satisfied: six>=1.5 in /home/john/anaconda3/envs/bettermdptools/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->bettermdptools) (1.16.0)

# %% [markdown]
# # Frozen Lake

# %%
import gymnasium as gym
from algorithms.planner import Planner
from examples.plots import Plots

# %%
# make gym environment 
frozen_lake = gym.make('FrozenLake8x8-v1', render_mode=None)

# run VI
V, V_track, pi = Planner(frozen_lake.P).value_iteration()

#plot state values
Plots.grid_values_heat_map(V, "State Values")
# Out:
# /home/john/anaconda3/lib/python3.11/site-packages/algorithms/planner.py:76: UserWarning: Max iterations reached before convergence.  Check theta and n_iters.
#   warnings.warn("Max iterations reached before convergence.  Check theta and n_iters.  ")
# runtime = 0.43 seconds
